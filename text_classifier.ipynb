# %%
import pandas as pd
from transformers import pipeline
import numpy as np
from tqdm import tqdm

# %%
books = pd.read_csv("Dataset/7k books/books_cleaned.csv")
books["categories"].value_counts().nlargest(10)
# Out:
# categories
# Fiction                      1835
# Juvenile Fiction              299
# Biography & Autobiography     265
# History                       176
# Literary Criticism            116
# Comics & Graphic Novels       107
# Philosophy                    104
# Religion                       98
# Drama                          71
# Science                        49
# Name: count, dtype: int64

# %%
category_mapping = {
    'Fiction' : "Fiction",
    'Juvenile Fiction': "Children's Fiction",
    'Biography & Autobiography': "Nonfiction",
    'History': "Nonfiction",
    'Literary Criticism': "Nonfiction",
    'Philosophy': "Nonfiction",
    'Religion': "Nonfiction",
    'Comics & Graphic Novels': "Fiction",
    'Drama': "Fiction",
    'Juvenile Nonfiction': "Children's Nonfiction",
    'Science': "Nonfiction",
    'Poetry': "Fiction"
 }

books["simple_categories"] = books["categories"].map(category_mapping)

# %%
fiction_categories = ["Fiction", "Nonfiction"]

pipe = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   6%|5         | 94.4M/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[0]

# %%
pipe(sequence, fiction_categories)
# Out:
# {'sequence': 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.',
#  'labels': ['Fiction', 'Nonfiction'],
#  'scores': [0.8438268899917603, 0.15617306530475616]}

# %%
max_index = np.argmax(pipe(sequence, fiction_categories)["scores"])
max_label = pipe(sequence, fiction_categories)["labels"][max_index]
max_label
# Out:
# 'Fiction'

# %%
def generate_predictions(sequence, categories):
    predictions = pipe(sequence, categories)
    max_index = np.argmax(predictions["scores"])
    max_label = predictions["labels"][max_index]
    return max_label

# %%
actual_categories = []
predicted_categories = []

for i in tqdm(range(0, 300)):
    sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[i]
    predicted_categories += [generate_predictions(sequence, fiction_categories)]
    actual_categories += ["Fiction"]
# Out:
# 100%|██████████| 300/300 [15:37<00:00,  3.12s/it]

# %%
for i in tqdm(range(0, 300)):
    sequence = books.loc[books["simple_categories"] == "Nonfiction", "description"].reset_index(drop=True)[i]
    predicted_categories += [generate_predictions(sequence, fiction_categories)]
    actual_categories += ["Nonfiction"]
# Out:
# 100%|██████████| 300/300 [11:51<00:00,  2.37s/it]

# %%
predictions_df = pd.DataFrame({"actual_categories": actual_categories, "predicted_categories": predicted_categories})
predictions_df
# Out:
#     actual_categories predicted_categories
# 0             Fiction              Fiction
# 1             Fiction              Fiction
# 2             Fiction              Fiction
# 3             Fiction           Nonfiction
# 4             Fiction              Fiction
# ..                ...                  ...
# 595        Nonfiction           Nonfiction
# 596        Nonfiction           Nonfiction
# 597        Nonfiction              Fiction
# 598        Nonfiction           Nonfiction
# 599        Nonfiction           Nonfiction
#
# [600 rows x 2 columns]

# %%
predictions_df["correct_prediction"] = (
    np.where(predictions_df["actual_categories"] == predictions_df["predicted_categories"], 1, 0)
)

# %%
predictions_df["correct_prediction"].sum() / len(predictions_df)
# Out:
# np.float64(0.7866666666666666)

# %%
isbns = []
predicted_categories = []

missing_categories = books.loc[books["simple_categories"].isna(), ["isbn13", "description"]].reset_index(drop=True)

# %%
for i in tqdm(range(0, len(missing_categories))):
    sequence = missing_categories["description"][i]
    predicted_categories += [generate_predictions(sequence, fiction_categories)]
    isbns += [missing_categories["isbn13"][i]]
# Out:
# 100%|██████████| 1292/1292 [47:00<00:00,  2.18s/it]

# %%
missing_predicted_df = pd.DataFrame({"isbn13": isbns, "predicted_categories": predicted_categories})
missing_predicted_df
# Out:
#              isbn13 predicted_categories
# 0     9780002261982              Fiction
# 1     9780006280897           Nonfiction
# 2     9780006280934           Nonfiction
# 3     9780006380832           Nonfiction
# 4     9780006470229              Fiction
# ...             ...                  ...
# 1287  9788125026600           Nonfiction
# 1288  9788171565641              Fiction
# 1289  9788172235222              Fiction
# 1290  9788173031014           Nonfiction
# 1291  9788179921623              Fiction
#
# [1292 rows x 2 columns]

# %%
books = pd.merge(books, missing_predicted_df, on="isbn13", how="left")
books["simple_categories"] = np.where(books["simple_categories"].isna(), books["predicted_categories"], books["simple_categories"])
books = books.drop(columns = ["predicted_categories"])

books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 4488  9788172235222  8172235224
# 4489  9788173031014  8173031010
# 4490  9788179921623  817992162X
# 4491  9788185300535  8185300534
# 4492  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 4488                                  Mistaken Identity
# 4489                                Journey to the East
# 4490  The Monk Who Sold His Ferrari: A Fable About F...
# 4491                                          I Am that
# 4492                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 4488                              Nayantara Sahgal
# 4489                                 Hermann Hesse
# 4490                                  Robin Sharma
# 4491  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 4492                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 4488        Indic fiction (English)
# 4489              Adventure stories
# 4490               Health & Fitness
# 4491                     Philosophy
# 4492                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 4488  http://books.google.com/books/content?id=q-tKP...
# 4489  http://books.google.com/books/content?id=rq6JP...
# 4490  http://books.google.com/books/content?id=c_7mf...
# 4491  http://books.google.com/books/content?id=Fv_JP...
# 4492  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 4488  On A Train Journey Home To North India After L...          2003.0
# 4489  This book tells the tale of a man who goes on ...          2002.0
# 4490  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 4491  This collection of the timeless teachings of o...          1999.0
# 4492  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 4488            2.93      324.0            0.0
# 4489            3.70      175.0           24.0
# 4490            3.82      198.0         1568.0
# 4491            4.51      531.0          104.0
# 4492            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 4488                                  Mistaken Identity
# 4489                                Journey to the East
# 4490  The Monk Who Sold His Ferrari: A Fable About F...
# 4491     I Am that: Talks with Sri Nisargadatta Maharaj
# 4492                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 4488  9788172235222 On A Train Journey Home To North...           Fiction
# 4489  9788173031014 This book tells the tale of a ma...        Nonfiction
# 4490  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 4491  9788185300535 This collection of the timeless ...        Nonfiction
# 4492  9789027712059 Since the three volume edition o...        Nonfiction
#
# [4493 rows x 14 columns]

# %%
books[books["categories"].str.lower().isin([
    "romance",
    "science fiction",
    "scifi",
    "fantasy",
    "horror",
    "mystery",
    "thriller",
    "comedy",
    "crime",
    "historical"
])]
# Out:
#              isbn13      isbn10                                     title  \
# 21    9780006513087  0006513085                                   Gravity
# 449   9780099410355  0099410354                                   Traitor
# 452   9780099422341  0099422344                            Yeats is Dead!
# 464   9780099446729  0099446723                            Blackwood Farm
# 977   9780261102422  0261102427                          The Silmarillion
# 1284  9780340837955  0340837950                Stranger in a Strange Land
# 2455  9780575075597  0575075597                                    Replay
# 2468  9780590254762  0590254766      The lion, the witch and the wardrobe
# 2810  9780739423851  0739423851                           Wizard's Castle
# 2811  9780739439708  0739439707                              Time Quartet
# 3059  9780760728505  076072850X              20,000 Leagues Under the Sea
# 3851  9781416502043  1416502041  The Voyage of the Jerle Shannara Trilogy
# 4292  9781841494081  1841494089            The Darkness that Comes Before
# 4347  9781857231359  185723135X                            Use of Weapons
# 4364  9781857989342  1857989341                       The Gods Themselves
#
#                         authors       categories  \
# 21               Tess Gerritsen  Science fiction
# 449     Matthew Woodring Stover  Science fiction
# 452             Joseph O'Connor           Comedy
# 464                   Anne Rice           Horror
# 977   John Ronald Reuel Tolkien          Fantasy
# 1284         Robert A. Heinlein  Science fiction
# 2455               Ken Grimwood          Fantasy
# 2468        Clive Staples Lewis          Fantasy
# 2810          Diana Wynne Jones          Fantasy
# 2811          Madeleine L'Engle  Science fiction
# 3059                Jules Verne  Science fiction
# 3851               Terry Brooks          Fantasy
# 4292            R. Scott Bakker          Fantasy
# 4347                 Iain Banks  Science fiction
# 4364               Isaac Asimov  Science fiction
#
#                                               thumbnail  \
# 21    http://books.google.com/books/content?id=KI66c...
# 449   http://books.google.com/books/content?id=VbICO...
# 452   http://books.google.com/books/content?id=DrE3I...
# 464   http://books.google.com/books/content?id=cIn8T...
# 977   http://books.google.com/books/content?id=22ePu...
# 1284  http://books.google.com/books/content?id=ZQhiP...
# 2455  http://books.google.com/books/content?id=9vmNP...
# 2468                                                NaN
# 2810  http://books.google.com/books/content?id=hB7hA...
# 2811                                                NaN
# 3059                                                NaN
# 3851  http://books.google.com/books/content?id=jqVsA...
# 4292  http://books.google.com/books/content?id=BG8qG...
# 4347                                                NaN
# 4364  http://books.google.com/books/content?id=8ClIP...
#
#                                             description  published_year  \
# 21    Emma Watson a research physician has been trai...          2004.0
# 449   From the depths of catastrophe, a glimmer of h...          2002.0
# 452   In aid of Amnesty International, this is a bri...          2002.0
# 464   Lestat Is Back, Saviour And Demon, Presiding O...          2003.0
# 977   Tolkien's Silmarillion is the core work of the...          1999.0
# 1284  Epic, entertaining, Stranger in a Strange Land...          2005.0
# 2455  At forty-three Jeff Winston is tired of his lo...          2005.0
# 2468  Four English school children enter the magic l...          1995.0
# 2810  Howl's moving castle - Eldest of three sisters...          2002.0
# 2811  Blending magic with quantum physics, Madeleine...          2003.0
# 3059  Retells the adventures of a French professor a...          2002.0
# 3851  When the body of a half-drowned elf is found f...          2004.0
# 4292  A score of centuries has passed since the Firs...          2005.0
# 4347  The man known as Cheradenine Zakalwe was one o...          1992.0
# 4364  In the year 2100, mankind on Earth, settlers i...          2000.0
#
#       average_rating  num_pages  ratings_count  \
# 21              4.04      342.0         8024.0
# 449             4.00      320.0         6765.0
# 452             3.39      298.0           34.0
# 464             3.86      774.0        26145.0
# 977             3.91      384.0          253.0
# 1284            3.92      672.0          563.0
# 2455            4.16      272.0          412.0
# 2468            4.21      189.0          860.0
# 2810            4.44      376.0          439.0
# 2811            4.35      646.0          165.0
# 3059            3.88      394.0       135778.0
# 3851            4.26     1260.0           84.0
# 4292            3.79      638.0          317.0
# 4347            4.19      411.0        30779.0
# 4364            4.09      288.0        41304.0
#
#                                     title_and_subtitle  \
# 21                                             Gravity
# 449                                            Traitor
# 452   Yeats is Dead!: A Novel by Fifteen Irish Writers
# 464                                     Blackwood Farm
# 977                                   The Silmarillion
# 1284                        Stranger in a Strange Land
# 2455                                            Replay
# 2468              The lion, the witch and the wardrobe
# 2810                                   Wizard's Castle
# 2811                                      Time Quartet
# 3059                      20,000 Leagues Under the Sea
# 3851          The Voyage of the Jerle Shannara Trilogy
# 4292                    The Darkness that Comes Before
# 4347                                    Use of Weapons
# 4364                               The Gods Themselves
#
#                                      tagged_description simple_categories
# 21    9780006513087 Emma Watson a research physician...        Nonfiction
# 449   9780099410355 From the depths of catastrophe, ...           Fiction
# 452   9780099422341 In aid of Amnesty International,...           Fiction
# 464   9780099446729 Lestat Is Back, Saviour And Demo...           Fiction
# 977   9780261102422 Tolkien's Silmarillion is the co...           Fiction
# 1284  9780340837955 Epic, entertaining, Stranger in ...           Fiction
# 2455  9780575075597 At forty-three Jeff Winston is t...           Fiction
# 2468  9780590254762 Four English school children ent...        Nonfiction
# 2810  9780739423851 Howl's moving castle - Eldest of...           Fiction
# 2811  9780739439708 Blending magic with quantum phys...           Fiction
# 3059  9780760728505 Retells the adventures of a Fren...           Fiction
# 3851  9781416502043 When the body of a half-drowned ...           Fiction
# 4292  9781841494081 A score of centuries has passed ...        Nonfiction
# 4347  9781857231359 The man known as Cheradenine Zak...        Nonfiction
# 4364  9781857989342 In the year 2100, mankind on Ear...           Fiction
